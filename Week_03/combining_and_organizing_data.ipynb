# %% [markdown]
# # Combining & organizing data

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import numpy as np
import fnmatch

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/applied_research_methods/Week_03

# %% [markdown]
# ## Importing the prepared rental apartments data

# %%
# Read data to pandas data frame
df_orig = pd.read_csv('./Data/apartments_data_prepared.csv', 
                      sep=',', 
                      encoding='utf-8')

# Copy of data with selected colums
columns = [ 'web-scraper-order', 
            'address_raw',
            'rooms', 
            'area', 
            'luxurious',
            'price',
            'price_per_m2']
df = df_orig[columns]

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# (860, 7)
#   web-scraper-order                          address_raw  rooms  area  \
# 0      1693998201-1    Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0  49.0
# 1      1693998201-2   Zürcherstrasse 1, 8173 Neerach, ZH    3.5  65.0
# 2      1693998201-4  Cramerstrasse 8-12, 8004 Zürich, ZH    2.0  54.0
# 3      1693998201-5    Rotachstrasse 33, 8003 Zürich, ZH    2.0  49.0
# 4     1693998201-16      Wolframplatz 1, 8045 Zürich, ZH    2.0  32.0
#
#    luxurious   price  price_per_m2
# 0          0  1441.0         29.41
# 1          0  1850.0         28.46
# 2          0  4853.0         89.87
# 3          0  4335.0         88.47
# 4          0  3515.0        109.84

# %% [markdown]
# ## Combining data from different sources

# %% [markdown]
# ### Reading rental apartment data with geocoded addresses

# %%
# Meaning of variables
# lat: geographical latitude
# lon: geographical longitude
# bfs_number: official municipality id
# bfs_name: official municipality name

# Geocoded data (i.e. data with latitude and longitude)
df_geo = pd.read_csv('./Data/apartments_data_geocoded.csv', 
                     sep=',', 
                     encoding='utf-8')

# Show data
df_geo[['web-scraper-order',
        'address_raw',
        'lat', 
        'lon', 
        'bfs_number', 
        'bfs_name']].head()
# Out:
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252167
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH  47.513332
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH  47.370792
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH  47.362282
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH  47.407925
#
#         lon  bfs_number   bfs_name
# 0  8.845798         118  Rüti (ZH)
# 1  8.474851          88    Neerach
# 2  8.514748         261     Zürich
# 3  8.522193         261     Zürich
# 4  8.392561         243   Dietikon

# %% [markdown]
# ### Join geo-information to rental apartment data using .merge()

# %%
df2 = df.merge(df_geo[['web-scraper-order', 
                       'lat', 
                       'lon', 
                       'bfs_number', 
                       'bfs_name']], 
               on="web-scraper-order")
df2.head()
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number   bfs_name
# 0          0  1441.0         29.41  47.252167  8.845798         118  Rüti (ZH)
# 1          0  1850.0         28.46  47.513332  8.474851          88    Neerach
# 2          0  4335.0         88.47  47.370792  8.514748         261     Zürich
# 3          0  3515.0        109.84  47.362282  8.522193         261     Zürich
# 4          0  3200.0         30.48  47.407925  8.392561         243   Dietikon

# %% [markdown]
# ### Reading municipality-level data

# %%
# Meaning of variables:
# bfs_number: official municipality id
# bfs_name: official municipality name
# pop: number of residents (=population)
# pop_dens: population density (pop per km2)
# frg_pct: percentage foreigners
# emp: numer of employees
# mean_taxable_income: mean taxable income

df_municip = pd.read_excel('./Data/municipality_data_with_taxable_income.xlsx', 
                           sheet_name='data_for_import')
df_municip.head(5)
# Out:
#    bfs_number            bfs_name    pop     pop_dens    frg_pct     emp  \
# 0           1     Aeugst am Albis   1981   250.442478  14.184755   442.0
# 1           2  Affoltern am Albis  12303  1161.756374  28.700317  6920.0
# 2           3          Bonstetten   5572   749.932705  16.564968  1014.0
# 3           4     Hausen am Albis   3751   275.808824  16.022394  1021.0
# 4           5            Hedingen   3778   578.560490  16.410799  1478.0
#
#    mean_taxable_income
# 0        105013.570634
# 1         71059.805603
# 2         88927.698145
# 3         86300.455137
# 4         90811.205330

# %% [markdown]
# ### Join municipality data to rental apartment data using .merge()

# %%
# Merge needs a key which must be identical in both data sets (here the key is 'bfs_number')
df3 = df2.merge(df_municip[['bfs_number', 
                            'pop', 
                            'pop_dens', 
                            'frg_pct', 
                            'emp',
                            'mean_taxable_income']], 
                on="bfs_number")
df3.head(5)
# Out:
#   web-scraper-order                           address_raw  rooms   area  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH    3.0   49.0
# 1      1693998201-2    Zürcherstrasse 1, 8173 Neerach, ZH    3.5   65.0
# 2      1693998201-5     Rotachstrasse 33, 8003 Zürich, ZH    2.0   49.0
# 3     1693998201-16       Wolframplatz 1, 8045 Zürich, ZH    2.0   32.0
# 4     1693998205-25  Badenerstrasse 67, 8953 Dietikon, ZH    3.5  105.0
#
#    luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 0          0  1441.0         29.41  47.252167  8.845798         118
# 1          0  1850.0         28.46  47.513332  8.474851          88
# 2          0  4335.0         88.47  47.370792  8.514748         261
# 3          0  3515.0        109.84  47.362282  8.522193         261
# 4          0  3200.0         30.48  47.407925  8.392561         243
#
#     bfs_name     pop     pop_dens    frg_pct       emp  mean_taxable_income
# 0  Rüti (ZH)   12286  1221.272366  24.841283    5053.0         65362.042683
# 1    Neerach    3175   525.662252  13.322835     641.0        111422.358722
# 2     Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 3     Zürich  420217  4778.994655  32.458468  491193.0         82932.737704
# 4   Dietikon   27746  2970.663812  46.226483   18911.0         64662.737784

# %% [markdown]
# ### Export data to file

# %%
# Remove missing values which may have ocured from the merging process
df3 = df3.dropna()

# Check for missing values per column
print(df3.isna().sum().sum())

# Remove duplicates
df3 = df3.drop_duplicates()

# Check for duplicates
print(df3.duplicated().sum().sum())

# Count number of rows and columns
print(df3.shape)

# Export apartment data to file
df3.to_csv('./Data/apartments_data_enriched.csv',
            sep=',',
            encoding='utf-8')
# Out:
# 0
# 0
# (780, 16)

# %% [markdown]
# ### Sorting data

# %%
# Sorting data by 'price' and 'area' with highest price above (ascending=False)
df3.sort_values(by=['price', 'area'], 
                ascending=False).head()
# Out:
#     web-scraper-order                               address_raw  rooms   area  \
# 260    1693998265-365      Gustav-Gull-Platz 4, 8004 Zürich, ZH    4.5  140.0
# 261    1693998265-366                 Engweg 8, 8006 Zürich, ZH    4.5  140.0
# 143    1693998236-207          Etzelstrasse 35, 8038 Zürich, ZH    3.5  100.0
# 345    1693998285-475    Universitätstrasse 41, 8006 Zürich, ZH    4.5  140.0
# 14      1693998205-38  Buckwiesstrasse 12, 8700 Küsnacht ZH, ZH    5.5  232.0
#
#      luxurious   price  price_per_m2        lat       lon  bfs_number  \
# 260          0  9950.0         71.07  47.379471  8.531120         261
# 261          0  9170.0         65.50  47.385265  8.537632         261
# 143          1  9150.0         91.50  47.346546  8.530695         261
# 345          0  8990.0         64.21  47.380440  8.547943         261
# 14           0  8500.0         36.64  47.319805  8.592113         154
#
#           bfs_name     pop     pop_dens    frg_pct       emp  \
# 260         Zürich  420217  4778.994655  32.458468  491193.0
# 261         Zürich  420217  4778.994655  32.458468  491193.0
# 143         Zürich  420217  4778.994655  32.458468  491193.0
# 345         Zürich  420217  4778.994655  32.458468  491193.0
# 14   Küsnacht (ZH)   14564  1178.317152  26.503708    6401.0
#
#      mean_taxable_income
# 260         82932.737704
# 261         82932.737704
# 143         82932.737704
# 345         82932.737704
# 14         174434.537050

# %% [markdown]
# ### Aggregation of data

# %%
# Aggregation using .groupby()
df3[['rooms', 'price']].groupby(['rooms']).mean()
# Out:
#              price
# rooms
# 1.0    1295.520000
# 1.5    1963.515152
# 2.0    2155.846154
# 2.5    2417.809859
# 3.0    1953.113636
# 3.5    2650.280000
# 4.0    2852.357143
# 4.5    3067.847561
# 5.0    2881.666667
# 5.5    3523.094340
# 6.0    3450.000000
# 6.5    3787.000000
# 7.0    6350.000000
# 7.5    4765.000000
# 8.5    8500.000000

# %% [markdown]
# ## Reshaping data

# %% [markdown]
# ### Reshaping data using .stack() and .unstack()

# %%
df_sub = df3[['bfs_name', 'rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

df_sub_stacked = df_sub.stack()
print('Stacked')
print(df_sub_stacked, '\n')

# Using unstack
print('Unstacked (= back to original shape)')
print(df_sub_stacked.unstack())
# Out:
# Original shape
#     bfs_name  rooms   price   area
# 0  Rüti (ZH)    3.0  1441.0   49.0
# 1    Neerach    3.5  1850.0   65.0
# 2     Zürich    2.0  4335.0   49.0
# 3     Zürich    2.0  3515.0   32.0
# 4   Dietikon    3.5  3200.0  105.0
#
# Stacked
# 0  bfs_name    Rüti (ZH)
#    rooms             3.0
#    price          1441.0
#    area             49.0
# 1  bfs_name      Neerach
#    rooms             3.5
#    price          1850.0
#    area             65.0
# 2  bfs_name       Zürich
#    rooms             2.0
#    price          4335.0
#    area             49.0
# 3  bfs_name       Zürich
#    rooms             2.0
#    price          3515.0
#    area             32.0
# 4  bfs_name     Dietikon
#    rooms             3.5
#    price          3200.0
#    area            105.0
# dtype: object
#
# Unstacked (= back to original shape)
#     bfs_name rooms   price   area
# 0  Rüti (ZH)   3.0  1441.0   49.0
# 1    Neerach   3.5  1850.0   65.0
# 2     Zürich   2.0  4335.0   49.0
# 3     Zürich   2.0  3515.0   32.0
# 4   Dietikon   3.5  3200.0  105.0

# %% [markdown]
# ### Reshaping data using .melt()

# %%
df_sub = df3[['rooms', 'price', 'area']][:5]
print('Original shape')
print(df_sub, '\n')

print('Reshaped using .melt()')
print(pd.melt(df, id_vars=['rooms'], value_vars=['price', 'area']))
# Out:
# Original shape
#    rooms   price   area
# 0    3.0  1441.0   49.0
# 1    3.5  1850.0   65.0
# 2    2.0  4335.0   49.0
# 3    2.0  3515.0   32.0
# 4    3.5  3200.0  105.0
#
# Reshaped using .melt()
#       rooms variable   value
# 0       3.0    price  1441.0
# 1       3.5    price  1850.0
# 2       2.0    price  4853.0
# 3       2.0    price  4335.0
# 4       2.0    price  3515.0
# ...     ...      ...     ...
# 1715    3.5     area    82.0
# 1716    4.0     area    73.0
# 1717    4.5     area   110.0
# 1718    3.0     area    68.0
# 1719    4.5     area   114.0
#
# [1720 rows x 3 columns]

# %% [markdown]
# ### Pivoting data using .pivot_table()

# %%
# Using pivot_table to reshape the data and calculate means 
pd.pivot_table(df3[['rooms', 'price', 'area']],
               index=['rooms'],
               values=['price', 'area', 'rooms'],
               aggfunc=(np.mean))
# Out:
#              area        price
# rooms
# 1.0     32.420000  1295.520000
# 1.5     35.969697  1963.515152
# 2.0     54.589744  2155.846154
# 2.5     66.880282  2417.809859
# 3.0     67.522727  1953.113636
# 3.5     89.380000  2650.280000
# 4.0     98.464286  2852.357143
# 4.5    115.060976  3067.847561
# 5.0    108.000000  2881.666667
# 5.5    153.811321  3523.094340
# 6.0    530.750000  3450.000000
# 6.5    256.357143  3787.000000
# 7.0    175.000000  6350.000000
# 7.5    205.000000  4765.000000
# 8.5    210.000000  8500.000000

# %% [markdown]
# add price_per_m2

# %%
# Using pivot_table to reshape the data and calculate means 
pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
               index=['rooms'],
               values=['price', 'area', 'rooms', 'price_per_m2'],
               aggfunc=(np.mean))
# Out:
#              area        price  price_per_m2
# rooms
# 1.0     32.420000  1295.520000     48.257400
# 1.5     35.969697  1963.515152     59.417576
# 2.0     54.589744  2155.846154     42.528462
# 2.5     66.880282  2417.809859     37.376338
# 3.0     67.522727  1953.113636     28.779091
# 3.5     89.380000  2650.280000     29.734100
# 4.0     98.464286  2852.357143     29.646429
# 4.5    115.060976  3067.847561     26.332622
# 5.0    108.000000  2881.666667     26.376667
# 5.5    153.811321  3523.094340     23.143396
# 6.0    530.750000  3450.000000     16.572500
# 6.5    256.357143  3787.000000     20.130714
# 7.0    175.000000  6350.000000     36.325000
# 7.5    205.000000  4765.000000     23.273333
# 8.5    210.000000  8500.000000     40.480000

# %% [markdown]
# Relationship between area and price per m2

# %%
#korrelation between price and area
correlation = df['area'].corr(df['price_per_m2'])
print(correlation)
# Out:
# -0.33724717889569367

# %% [markdown]
# Scatterplot

# %%
#erstelle mir ein scatterplot mit area und price_per_m2
import matplotlib.pyplot as plt
plt.scatter(df['area'], df['price_per_m2'])
plt.show()

# %% [markdown]
# ### 4e) Is there a relationship between the variable area and the price_per_m2?
# The correlation coefficient is -0.3 that means there is a slighlty negative dependence between area and price_per_m2 (= if the area rises, the price per m2 sinks - but the price per m2 is also dependent on location)

# %% [markdown]
# ### f

# %%
# Using pivot_table to reshape the data and calculate means 
pivot_table = pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
                             index=['rooms'],
                             values=['price'],
                             aggfunc='count')

# Rename the column for clarity
pivot_table.columns = ['Quantity']

# Display the pivot table
pivot_table
# Out:
#        Quantity
# rooms
# 1.0          50
# 1.5          33
# 2.0          39
# 2.5         142
# 3.0          44
# 3.5         200
# 4.0          28
# 4.5         164
# 5.0           3
# 5.5          53
# 6.0           4
# 6.5          14
# 7.0           2
# 7.5           3
# 8.5           1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Pivot-Tabelle erstellen, um die Anzahl der Einträge pro Zimmeranzahl zu berechnen
pivot_table = pd.pivot_table(df3[['rooms', 'price', 'area', 'price_per_m2']],
                             index=['rooms'],
                             values=['price'],
                             aggfunc='count')

# Umbenennen der Spalte für Klarheit
pivot_table.columns = ['count']

# Erstellen des Säulendiagramms
pivot_table['count'].plot(kind='bar')

# Hinzufügen von Titeln und Beschriftungen
plt.title('Anzahl der Einträge pro Zimmeranzahl')
plt.xlabel('Zimmeranzahl')
plt.ylabel('Anzahl der Einträge')

# Anzeigen des Diagramms
plt.show()

# %% [markdown]
# ### Distribution of Apartments
#
# Most of the Apartments have a number of rooms between 2,5 and 4.5.
# There is less apartments with a number of rooms over 5.5.

# %% [markdown]
# ### g)

# %%
# Using pivot_table to reshape the data and calculate means 
pivottable = pd.pivot_table(df3[['bfs_name', 'rooms', 'price', 'area', 'price_per_m2']],
               index=['bfs_name'],
               values=['price', 'area', 'rooms', 'price_per_m2'],
               aggfunc=(np.mean))

pivottable_sorted = pivottable.sort_values(by=['price', 'area'], ascending=False)
pivottable_sorted
# Out:
#                       area        price  price_per_m2     rooms
# bfs_name
# Rüschlikon      144.000000  6660.000000     46.250000  4.500000
# Küsnacht (ZH)   136.333333  4891.666667     35.476667  4.500000
# Nürensdorf      506.500000  4500.000000     17.605000  6.000000
# Maur            138.500000  4250.000000     30.445000  4.500000
# Obfelden        127.500000  4095.000000     31.910000  5.500000
# ...                    ...          ...           ...       ...
# Feuerthalen      81.428571  1613.428571     19.974286  3.642857
# Dättlikon        90.000000  1480.000000     16.440000  4.000000
# Weiach           46.000000  1420.000000     30.870000  1.500000
# Weiningen (ZH)   55.000000  1160.000000     19.710000  2.250000
# Herrliberg       18.000000  1150.000000     63.890000  1.000000
#
# [105 rows x 4 columns]

# %%
# Using pivot_table to reshape the data and calculate means 
pivottable = pd.pivot_table(df3[['bfs_name', 'rooms', 'price', 'area', 'price_per_m2']],
               index=['bfs_name'],
               values=['price', 'area', 'rooms', 'price_per_m2'],
               aggfunc=(np.mean))

pivottable_sorted = pivottable.sort_values(by='area', ascending=False)
pivottable_sorted
# Out:
#                       area        price  price_per_m2     rooms
# bfs_name
# Hettlingen      876.500000  3445.000000     13.655000  5.250000
# Weisslingen     585.000000  3250.000000      5.560000  6.500000
# Nürensdorf      506.500000  4500.000000     17.605000  6.000000
# Brütten         248.500000  4070.000000     16.315000  6.000000
# Knonau          195.000000  3445.000000     18.590000  4.750000
# ...                    ...          ...           ...       ...
# Opfikon          63.692308  2080.384615     37.764615  2.576923
# Weiningen (ZH)   55.000000  1160.000000     19.710000  2.250000
# Rümlang          48.000000  2850.000000     59.380000  2.000000
# Weiach           46.000000  1420.000000     30.870000  1.500000
# Herrliberg       18.000000  1150.000000     63.890000  1.000000
#
# [105 rows x 4 columns]

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-15 10:08:54
# Python Version: 3.11.10
# -----------------------------------
